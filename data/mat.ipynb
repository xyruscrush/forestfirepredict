# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
ages
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 885    39.0
# 886    27.0
# 887    19.0
# 889    26.0
# 890    32.0
# Name: age, Length: 714, dtype: float64

# %%
import pandas as pd
df=pd.read_csv('../bmi.csv')
df
# Out:
#      Age  Height  Weight        Bmi       BmiClass
# 0     61    1.85  109.30  31.935720  Obese Class 1
# 1     60    1.71   79.02  27.023700     Overweight
# 2     60    1.55   74.70  31.092612  Obese Class 1
# 3     60    1.46   35.90  16.841809    Underweight
# 4     60    1.58   97.10  38.896010  Obese Class 2
# ..   ...     ...     ...        ...            ...
# 736   34    1.86   95.70  27.662157     Overweight
# 737   44    1.91  106.90  29.302925     Overweight
# 738   25    1.82   88.40  26.687598     Overweight
# 739   35    1.88   98.50  27.868945     Overweight
# 740   45    1.93  109.90  29.504148     Overweight
#
# [741 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,8))
plt.plot(df.index[0:100],df['Height'][0:100],color='red',marker='*',markersize=2,linewidth=1,linestyle='-')

plt.xlabel('index')
plt.ylabel('Height')
plt.title('index vs height')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.bar(df.index[0:51],df.Age[0:51],color='blue',edgecolor='black',width=0.5)
plt.title('Basic Bar plot')
plt.xlabel('index')
plt.ylabel('Age')
plt.show()

# %%
plt.figure(figsize=(20,8))
import numpy as np
bins=np.linspace(data1.Age_.min(),data1.Age_.max(),8)
plt.hist(data1['Age_'],bins,color='skyblue',density=True,cumulative=True)
plt.xlabel('age')
plt.ylabel('count')
plt.title('age vs frequency')
plt.show()

# %%
data1
# Out:
#     Age_  Height_count  Weight_count
# 0     15            12            12
# 1     16            22            22
# 2     17            22            22
# 3     18            33            33
# 4     19            32            32
# 5     20            31            31
# 6     21            27            27
# 7     22            28            28
# 8     23            21            21
# 9     24            24            24
# 10    25            27            27
# 11    26            23            23
# 12    27            24            24
# 13    28            25            25
# 14    29            24            24
# 15    30            25            25
# 16    31            19            19
# 17    32            20            20
# 18    33            16            16
# 19    34            19            19
# 20    35            18            18
# 21    36            15            15
# 22    37            14            14
# 23    38            15            15
# ...

# %%
# Out:
# Range
# (14.999, 20.75]    6
# (20.75, 26.5]      6
# (26.5, 32.25]      6
# (32.25, 38.0]      6
# (38.0, 43.75]      5
# (43.75, 49.5]      6
# (49.5, 55.25]      6
# (55.25, 61.0]      6
# Name: Age_, dtype: int64

# %%
explode=np.random.rand(len(data2))
plt.figure(figsize=(20,10))
plt.pie(sizes,labels=labels,autopct='%1.1f%%',shadow=True,colors=['red','green','skyblue','yellow','orange','pink'])
plt.axis('equal')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.boxplot(df[['Age','Height','Weight']],labels=('1','2','3'))
plt.show()
# Out:
# C:\Users\xyrus\AppData\Local\Temp\ipykernel_7916\2253916636.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(df[['Age','Height','Weight']],labels=('1','2','3'))

# %%
df
# Out:
#      Age  Height  Weight        Bmi       BmiClass
# 0     61    1.85  109.30  31.935720  Obese Class 1
# 1     60    1.71   79.02  27.023700     Overweight
# 2     60    1.55   74.70  31.092612  Obese Class 1
# 3     60    1.46   35.90  16.841809    Underweight
# 4     60    1.58   97.10  38.896010  Obese Class 2
# ..   ...     ...     ...        ...            ...
# 736   34    1.86   95.70  27.662157     Overweight
# 737   44    1.91  106.90  29.302925     Overweight
# 738   25    1.82   88.40  26.687598     Overweight
# 739   35    1.88   98.50  27.868945     Overweight
# 740   45    1.93  109.90  29.504148     Overweight
#
# [741 rows x 5 columns]

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [3, 8, 1, 10, 5]

plt.plot(x, y, marker='o')
plt.title("Line Plot")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.show()

# %%
tips.sort_values('size')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 82        10.07  1.83  Female     No  Thur   Lunch     1
# 111        7.25  1.00  Female     No   Sat  Dinner     1
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1
# 222        8.58  1.92    Male    Yes   Fri   Lunch     1
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 185       20.69  5.00    Male     No   Sun  Dinner     5
# 125       29.80  4.20  Female     No  Thur   Lunch     6
# 143       27.05  5.00  Female     No  Thur   Lunch     6
# 156       48.17  5.00    Male     No   Sun  Dinner     6
# 141       34.30  6.70    Male     No  Thur   Lunch     6
#
# [244 rows x 7 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
custom_colors={"Female":'red',"Male":'blue'};
tips=sns.load_dataset('tips')
sns.set_theme(style='whitegrid')
sns.lineplot(x='size',y='total_bill',marker='o',hue='sex',data=tips,palette=custom_colors,)
plt.title("abc")
plt.show()
