# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('Algerian_forest_fires_dataset.csv',header=0)

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                day  month    year  Temperature    RH    Ws  \
# 122  Sidi-Bel Abbes Region Dataset    NaN     NaN          NaN   NaN   NaN
# 166                             14    7.0  2012.0         37.0  37.0  18.0
#
#      Rain   FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122    NaN   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 166    0.2  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %%
df.loc[:122,'region']=0
df.loc[123:,'region']=1

# %%
df
# Out:
#     day  month    year  Temperature    RH    Ws  Rain   FFMC   DMC    DC  ISI  \
# 0     1    6.0  2012.0         29.0  57.0  18.0    0.0  65.7   3.4   7.6  1.3
# 1     2    6.0  2012.0         29.0  61.0  13.0    1.3  64.4   4.1   7.6  1.0
# 2     3    6.0  2012.0         26.0  82.0  22.0   13.1  47.1   2.5   7.1  0.3
# 3     4    6.0  2012.0         25.0  89.0  13.0    2.5  28.6   1.3   6.9  0.0
# 4     5    6.0  2012.0         27.0  77.0  16.0    0.0  64.8   3.0  14.2  1.2
# ..   ..    ...     ...          ...   ...   ...    ...   ...   ...   ...  ...
# 240  26    9.0  2012.0         30.0  65.0  14.0    0.0  85.4  16.0  44.5  4.5
# 241  27    9.0  2012.0         28.0  87.0  15.0    4.4  41.1   6.5     8  0.1
# 242  28    9.0  2012.0         27.0  87.0  29.0    0.5  45.9   3.5   7.9  0.4
# 243  29    9.0  2012.0         24.0  54.0  18.0    0.1  79.7   4.3  15.2  1.7
# 244  30    9.0  2012.0         24.0  64.0  15.0    0.2  67.3   3.8  16.5  1.2
#
# ...

# %%
df
# Out:
#     day  month    year  Temperature    RH    Ws  Rain   FFMC   DMC    DC  ISI  \
# 0     1    6.0  2012.0         29.0  57.0  18.0    0.0  65.7   3.4   7.6  1.3
# 1     2    6.0  2012.0         29.0  61.0  13.0    1.3  64.4   4.1   7.6  1.0
# 2     3    6.0  2012.0         26.0  82.0  22.0   13.1  47.1   2.5   7.1  0.3
# 3     4    6.0  2012.0         25.0  89.0  13.0    2.5  28.6   1.3   6.9  0.0
# 4     5    6.0  2012.0         27.0  77.0  16.0    0.0  64.8   3.0  14.2  1.2
# ..   ..    ...     ...          ...   ...   ...    ...   ...   ...   ...  ...
# 240  26    9.0  2012.0         30.0  65.0  14.0    0.0  85.4  16.0  44.5  4.5
# 241  27    9.0  2012.0         28.0  87.0  15.0    4.4  41.1   6.5     8  0.1
# 242  28    9.0  2012.0         27.0  87.0  29.0    0.5  45.9   3.5   7.9  0.4
# 243  29    9.0  2012.0         24.0  54.0  18.0    0.1  79.7   4.3  15.2  1.7
# 244  30    9.0  2012.0         24.0  64.0  15.0    0.2  67.3   3.8  16.5  1.2
#
# ...

# %%
df.drop(123)
# Out:
#     day  month    year  Temperature    RH    Ws  Rain   FFMC   DMC    DC  ISI  \
# 0     1    6.0  2012.0         29.0  57.0  18.0    0.0  65.7   3.4   7.6  1.3
# 1     2    6.0  2012.0         29.0  61.0  13.0    1.3  64.4   4.1   7.6  1.0
# 2     3    6.0  2012.0         26.0  82.0  22.0   13.1  47.1   2.5   7.1  0.3
# 3     4    6.0  2012.0         25.0  89.0  13.0    2.5  28.6   1.3   6.9  0.0
# 4     5    6.0  2012.0         27.0  77.0  16.0    0.0  64.8   3.0  14.2  1.2
# ..   ..    ...     ...          ...   ...   ...    ...   ...   ...   ...  ...
# 240  26    9.0  2012.0         30.0  65.0  14.0    0.0  85.4  16.0  44.5  4.5
# 241  27    9.0  2012.0         28.0  87.0  15.0    4.4  41.1   6.5     8  0.1
# 242  28    9.0  2012.0         27.0  87.0  29.0    0.5  45.9   3.5   7.9  0.4
# 243  29    9.0  2012.0         24.0  54.0  18.0    0.1  79.7   4.3  15.2  1.7
# 244  30    9.0  2012.0         24.0  64.0  15.0    0.2  67.3   3.8  16.5  1.2
#
# ...

# %%
df.drop(122,inplace=True)

# %%
df.dropna()
# Out:
#     day  month    year  Temperature    RH    Ws  Rain   FFMC   DMC    DC  ISI  \
# 0     1    6.0  2012.0         29.0  57.0  18.0    0.0  65.7   3.4   7.6  1.3
# 1     2    6.0  2012.0         29.0  61.0  13.0    1.3  64.4   4.1   7.6  1.0
# 2     3    6.0  2012.0         26.0  82.0  22.0   13.1  47.1   2.5   7.1  0.3
# 3     4    6.0  2012.0         25.0  89.0  13.0    2.5  28.6   1.3   6.9  0.0
# 4     5    6.0  2012.0         27.0  77.0  16.0    0.0  64.8   3.0  14.2  1.2
# ..   ..    ...     ...          ...   ...   ...    ...   ...   ...   ...  ...
# 240  26    9.0  2012.0         30.0  65.0  14.0    0.0  85.4  16.0  44.5  4.5
# 241  27    9.0  2012.0         28.0  87.0  15.0    4.4  41.1   6.5     8  0.1
# 242  28    9.0  2012.0         27.0  87.0  29.0    0.5  45.9   3.5   7.9  0.4
# 243  29    9.0  2012.0         24.0  54.0  18.0    0.1  79.7   4.3  15.2  1.7
# 244  30    9.0  2012.0         24.0  64.0  15.0    0.2  67.3   3.8  16.5  1.2
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 244 entries, 0 to 244
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    object
#  1   month        244 non-null    float64
#  2   year         244 non-null    float64
#  3   Temperature  244 non-null    float64
#  4    RH          244 non-null    float64
#  5    Ws          244 non-null    float64
#  6   Rain         244 non-null    float64
#  7   FFMC         244 non-null    float64
#  8   DMC          244 non-null    float64
#  9   DC           244 non-null    object
#  10  ISI          244 non-null    float64
#  11  BUI          244 non-null    float64
#  12  FWI          244 non-null    object
#  13  Classes      243 non-null    object
#  14  region       244 non-null    float64
# dtypes: float64(11), object(4)
# memory usage: 30.5+ KB

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'region'],
#       dtype='object')

# %%
df.columns=df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'region'],
#       dtype='object')

# %%
df[['day','month','year','Temperature','RH','Ws']]=df[['day','month','year','Temperature','RH','Ws']].astype(int)

# %%
df
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4
# 1      2      6  2012           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9
# 2      3      6  2012           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7
# 3      4      6  2012           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7
# 4      5      6  2012           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 240   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 241   27      9  2012           28  87  15   4.4  41.1   6.5     8  0.1   6.2
# 242   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 243   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 244   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI       Classes  region
# ...

# %%
df.dropna(inplace=True)

# %%
df['FWI']=df['FWI'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 243 entries, 0 to 244
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
#  14  region       243 non-null    float64
# dtypes: float64(7), int64(6), object(2)
# memory usage: 30.4+ KB

# %%
df.isnull().any()
# Out:
# day            False
# month          False
# year           False
# Temperature    False
# RH             False
# Ws             False
# Rain           False
# FFMC           False
# DMC            False
# DC             False
# ISI            False
# BUI            False
# FWI            False
# Classes        False
# region         False
# dtype: bool

# %%
df['Classes']=df['Classes'].str.strip()

# %%
df['Classes']=df['Classes'].map(lambda x:0 if x=='not fire' else 1)

# %%
df['Classes'].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
df_copy=df.drop(['day','month','year'],axis=1)

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'region'],
#       dtype='object')

# %%
df_copy['DC']=df_copy['DC'].astype(float)

# %%
df_copy.hist(bins=50,figsize=(20,15))
plt.show()

# %%
size=df_copy['Classes'].value_counts()

# %%
size
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
labels=["Fire","Not-Fire"]
plt.pie(size,labels=labels,autopct='%1.1f%%')
plt.show()

# %%
df_copy.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.651400 -0.284510 -0.326492  0.676568  0.485687
# RH             -0.651400  1.000000  0.244048  0.222356 -0.644873 -0.408519
# Ws             -0.284510  0.244048  1.000000  0.171506 -0.166548 -0.000721
# Rain           -0.326492  0.222356  0.171506  1.000000 -0.543906 -0.288773
# FFMC            0.676568 -0.644873 -0.166548 -0.543906  1.000000  0.603608
# DMC             0.485687 -0.408519 -0.000721 -0.288773  0.603608  1.000000
# DC              0.376284 -0.226941  0.079135 -0.298023  0.507397  0.875925
# ISI             0.603871 -0.686667  0.008532 -0.347484  0.740007  0.680454
# BUI             0.459789 -0.353841  0.031438 -0.299852  0.592011  0.982248
# FWI             0.566670 -0.580957  0.032368 -0.324422  0.691132  0.875864
# Classes         0.516015 -0.432161 -0.069964 -0.379097  0.769492  0.585658
# ...

# %%
sns.heatmap(df_copy.corr())
# Out:
# <Axes: >

# %%
sns.countplot(x='month',data=df,hue='Classes')
# Out:
# <Axes: xlabel='month', ylabel='count'>

# %%
df.to_csv('Algerian_forest_fires_dataset_cleaned.csv',index=False)
